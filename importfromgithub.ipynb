# %%
import pandas as pd 
url='https://raw.githubusercontent.com/alhaol/csv/master/List.csv'
c=pd.read_csv(url)

# %%
c=pd.read_csv(url)

# %%
import pandas as pd
import io
import requests
url='https://raw.githubusercontent.com/alhaol/csv/master/List.csv'
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
url='https://github.com/alhaol/csv/blob/master/List.csv'

# %%
import pandas as pd
import io
import requests
url="https://github.com/alhaol/csv/blob/master/List.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-2da654a51f98> in <module>()
#       4 url="https://github.com/alhaol/csv/blob/master/List.csv"
#       5 s=requests.get(url).content
# ----> 6 c=pd.read_csv(io.StringIO(s.decode('utf-8')))
#
# ...

# %%
c
# Out:
#                                                  Name           ID      Fold
# 0                      Learn your ABCs: Kids Alphabet  IAL0OzsNGJM    Basics
# 1           How to Write the ABCs: Capital  Lowercase  _fTeS5-rQBQ    Basics
# 2   Lets Learn About the Four Seasons - Spring Sum...  D6yQ8-M8rmU   Advance
# 3                            01 Welcome to Arithmetic  -CtVTRgyWEI      Math
# 4                    02 Arithmetic: Intro to Addition  1Sco_XzEeh4      Math
# 5     03 Arithmetic: Commutative Property of Addition  Zj3pJOJTziM      Math
# 6     04 Arithmetic: Associative Property of Addition  OB_AS61L3jI      Math
# 7          05 Arithmetic: Introduction to Subtraction  wtvRyA9s_9M      Math
# 8                    06 Arithmetic: What are Integers  hZ6WEatAfjI      Math
# 9      07 Arithmetic: What is the symbol for Integers  yNT-W6ndBNs      Math
# 10      08 Arithmetic: Introduction to Multiplication  Qi5ATIWFblA      Math
# ...
